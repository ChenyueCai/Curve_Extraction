# %%
import skimage.io as skio
import numpy as np

# %%
figure2 = skio.imread('figure2.png')

# %%
skio.imshow(figure2)

# %%
figure2 = np.delete(figure2, 3,2)

# %%
import cv2

# %%
figure2_resize = cv2.resize(figure2, (150,150))

# %%
skio.imshow(figure2_resize)

# %%
r_zero, g_zero, b_zero = [],[],[]

# %%
for cord in contrain_zero:
    if cord[2] == 0:
        r_zero.append(cord[0:2])
    elif cord[2] == 1:
        g_zero.append(cord[0:2])
    elif cord[2] == 2:
        b_zero.append(cord[0:2])

# %%
r = set([tuple(x) for x in r_zero])
g = set([tuple(x) for x in g_zero])
b = set([tuple(x) for x in b_zero])
black = np.array([x for x in r & b&g])

# %%
import matplotlib.pyplot as plt

# %%
black_x = black[:,0]

# %%
black_y = black[:,1]

# %%
plt.scatter(black_y*(826/150)*(100/826), (150 -black_x)*(878/150)*(160/878))

# %%
black_x, black_y = black_y*(826/150)*(100/826), (150 -black_x)*(878/150)*(160/878)

# %%
plt.scatter(black_x,black_y)

# %%
black_cord_final = []
for i in np.arange(0,38,0.25):
    sum_num = 0
    num = 0
    for j in black_x:
        if j>=i and j<i+0.25:
            range_num = black_y[np.where(black_x==j)]
            num += len(range_num)
            sum_num += sum(range_num)
    if num!= 0:
        black_cord_final.append( [i+0.125, sum_num/num])

# %%
plt.scatter(np.array(black_cord_final)[:,0],np.array(black_cord_final)[:,1])

# %%
black_cord_final = []
for i in np.arange(0,38,0.25):
    min_num = []
    for j in black_x:
        if j>=i and j<i+0.25:
            range_num = black_y[np.where(black_x==j)]
            min_num.append(min(range_num))
    if min_num!=[]:
        black_cord_final.append( [i+0.125, min(min_num)])

# %%
plt.scatter(np.array(black_cord_final)[:,0],np.array(black_cord_final)[:,1])

# %%
black_cord_final = []
for i in np.arange(0,38,0.25):
    max_num = []
    for j in black_x:
        if j>=i and j<i+0.25:
            range_num = black_y[np.where(black_x==j)]
            max_num.append(max(range_num))
    if max_num!=[]:
        black_cord_final.append( [i+0.125, min(max_num)])

# %%
plt.scatter(np.array(black_cord_final)[:,0],np.array(black_cord_final)[:,1])
